# %% [markdown]
# # Setting the Dataset up

# %%
#Importing necessary libraries 
import pandas as pd
import sqlite3

# %%
#collecting wikipedia data as a data frame
data=pd.read_html('https://en.wikipedia.org/wiki/List_of_companies_of_India#Largest_firms', header=0)

# %%
#viewing the collected data
#The following data gives the details about major corporations in India
data[1]
# Out:
#                       Name           Industry  \
# 0                     Name           Industry
# 1    63 Moons Technologies         Technology
# 2            Aban Offshore             Energy
# 3             ABG Shipyard        Industrials
# 4                ABP Group  Consumer services
# ..                     ...                ...
# 474    Zensar Technologies         Technology
# 475                   Zeta         Technology
# 476       Zoho Corporation         Technology
# 477                 Zomato         Technology
# 478     Zydus Lifesciences        Health care
#
#                                            Sector  Headquarters  Founded  \
# 0                                          Sector  Headquarters  Founded
# 1                                        Software        Mumbai     1988
# 2    Oil & gas offshore drilling & other services       Chennai     1986
# 3                                    Shipbuilding     Ahmedabad     1985
# 4                    Broadcasting & entertainment       Kolkata     1922
# ..                                            ...           ...      ...
# 474                        Software & IT services          Pune     1991
# 475                     Consumer digital services        Mumbai     2015
# 476                                      Software       Chennai     1996
# 477                     Consumer digital services      Gurugram     2008
# 478                               Pharmaceuticals     Ahmedabad     1952
#
#                             Notes Status Status.1 Ownership_Status  \
# 0                           Notes    NaN      NaN              NaN
# 1            Financial technology      P        A                P
# 2              Oil, petrochemical      P        A                P
# 3                   Ship building      P        A                P
# 4                     Media, news      P        A                P
# ..                            ...    ...      ...              ...
# 474      IT services and software      P        A                P
# 475                       Fintech      P        A                P
# 476  Business management software      P        A                P
# 477                 Food delivery      P        A                P
# 478                        Pharma      P        A                P
#
#     Present_Status
# 0              NaN
# 1                A
# 2                A
# 3                A
# 4                A
# ..             ...
# 474              A
# 475              A
# 476              A
# 477              A
# 478              A
#
# [479 rows x 10 columns]

# %%
#creating a database with the data
df=data[1]

# %%
df.columns
# Out:
# Index(['Name', 'Industry', 'Sector', 'Headquarters', 'Founded', 'Notes',
#        'Status', 'Status.1'],
#       dtype='object')

# %%
#Renaming the column names 
df['Ownership_Status'] = df['Status']
df['Present_Status'] = df['Status.1']

# %%
#removing the first row, which is not required
df_c = df.drop(index=0, columns=["Status", "Status.1"])
df_c
# Out:
#                       Name           Industry  \
# 1    63 Moons Technologies         Technology
# 2            Aban Offshore             Energy
# 3             ABG Shipyard        Industrials
# 4                ABP Group  Consumer services
# 5                      ACC        Industrials
# ..                     ...                ...
# 474    Zensar Technologies         Technology
# 475                   Zeta         Technology
# 476       Zoho Corporation         Technology
# 477                 Zomato         Technology
# 478     Zydus Lifesciences        Health care
#
#                                            Sector Headquarters Founded  \
# 1                                        Software       Mumbai    1988
# 2    Oil & gas offshore drilling & other services      Chennai    1986
# 3                                    Shipbuilding    Ahmedabad    1985
# 4                    Broadcasting & entertainment      Kolkata    1922
# 5                                          Cement       Mumbai    1936
# ..                                            ...          ...     ...
# 474                        Software & IT services         Pune    1991
# 475                     Consumer digital services       Mumbai    2015
# 476                                      Software      Chennai    1996
# 477                     Consumer digital services     Gurugram    2008
# 478                               Pharmaceuticals    Ahmedabad    1952
#
#                             Notes Ownership_Status Present_Status
# 1            Financial technology                P              A
# 2              Oil, petrochemical                P              A
# 3                   Ship building                P              A
# 4                     Media, news                P              A
# 5                          Cement                P              A
# ..                            ...              ...            ...
# 474      IT services and software                P              A
# 475                       Fintech                P              A
# 476  Business management software                P              A
# 477                 Food delivery                P              A
# 478                        Pharma                P              A
#
# [478 rows x 8 columns]

# %%
df_c.columns
# Out:
# Index(['Name', 'Industry', 'Sector', 'Headquarters', 'Founded', 'Notes',
#        'Ownership_Status', 'Present_Status'],
#       dtype='object')

# %%
#Creating a connection
conn=sqlite3.connect('companies.db')
c=conn.cursor()

# %%
#Creating the table
c.execute(
    """ CREATE TABLE IF NOT EXISTS company('Name' text, 'Industry' text, 'Sector' text, 'Headquarters' text, 
    'Founded' int, 'Notes' text,'Ownership_Status' text, 'Present_Status' text);""")

# %%
#Adding data to table
df_c.to_sql('company', conn, if_exists='replace', index=False)
# Out:
# 478

# %%
#Creating a wrapper function
def rsql(query):
    return pd.read_sql_query(query, conn)

# %% [markdown]
# ## Using WHERE, LIMIT

# %%
rsql('SELECT * from company where "Industry" = "Technology" LIMIT 5')
# Out:
#                     Name    Industry                     Sector Headquarters  \
# 0  63 Moons Technologies  Technology                   Software    Bangalore
# 1               BluSmart  Technology  Consumer digital services     Gurugram
# 2        Cosmic Circuits  Technology             Semiconductors    Bengaluru
# 3                 Cyient  Technology     Software & IT services    Hyderabad
# 4               Flipkart  Technology  Consumer digital services    Bengaluru
#
#   Founded                                              Notes Ownership_Status  \
# 0    1988                               Financial technology                P
# 1    2019                        Taxi services, ride-sharing                P
# 2    2005           Acquired by Cadence Design Systems (USA)                P
# 3    1991  Engineering outsourcing services, software man...                P
# 4    2007                                         E-commerce                P
#
#   Present_Status
# 0              A
# 1              A
# 2              D
# 3              A
# 4              A

# %% [markdown]
# ## Using AS, COUNT, GROUP BY, ORDER BY, DESC, LIMIT

# %%
#Finding Top 5 cities with the most headquarters
rsql("""SELECT "Headquarters" as "City", COUNT("Headquarter") as "Number_of_HQs" 
from company group by "Headquarters" 
order by count("headquarters") DESC LIMIT 5""")
# Out:
#         City  Number_of_HQs
# 0     Mumbai            145
# 1  New Delhi             62
# 2  Bengaluru             45
# 3    Chennai             30
# 4    Kolkata             28

# %%
#Count of companies by Industries
rsql("SELECT Industry, COUNT(*) AS Company_Count FROM company GROUP BY Industry ORDER BY Company_Count DESC LIMIT 5")
# Out:
#          Industry  Company_Count
# 0     Industrials            109
# 1  Consumer goods             68
# 2      Financials             51
# 3    Conglomerate             44
# 4      Technology             38

# %%
#Finding count of companies by ownership status
rsql("SELECT Ownership_Status, COUNT(*) AS Total_Companies FROM company GROUP BY Ownership_Status")
# Out:
#   Ownership_Status  Total_Companies
# 0                P              378
# 1                S              100

# %% [markdown]
# ## USING AVG

# %%
#Finding the average age of Companies by Industry
rsql(""" SELECT Industry, Avg(2025-"Founded") as "Avg_Age_of_Companies" from company group by "Industry" """)
# Out:
#               Industry  Avg_Age_of_Companies
# 0      Basic materials             64.678571
# 1            Chemicals             56.470588
# 2         Conglomerate            131.340909
# 3       Consumer goods             86.073529
# 4    Consumer services             43.484848
# 5               Energy             46.733333
# 6           Financials             69.784314
# 7          Health care            126.821429
# 8          Industrials             50.944954
# 9            Insurance             16.000000
# 10            Railways             46.000000
# 11         Real estate             52.600000
# 12              Retail             27.900000
# 13          Technology             23.868421
# 14  Telecommunications             33.777778
# 15           Utilities             60.533333

# %% [markdown]
# ## USING BETWEEN, AND

# %%
#Companies founded between 2000 and 2010 in Technology Industry 
rsql("""SELECT COUNT(*) AS Tech_Companies_From_2000_to_2010 
FROM company WHERE Founded between 2000 AND 2010
AND Industry = 'Technology'""")
# Out:
#    Tech_Companies_From_2000_to_2010
# 0                                13

# %% [markdown]
# ## Using HAVING

# %%
#Finding industries with more than 10 companies using HAVING FUNCTION
rsql("SELECT Industry, COUNT(*) as Company_Count FROM company GROUP BY Industry HAVING COUNT(*) > 10")
# Out:
#              Industry  Company_Count
# 0     Basic materials             28
# 1           Chemicals             17
# 2        Conglomerate             44
# 3      Consumer goods             68
# 4   Consumer services             33
# 5              Energy             15
# 6          Financials             51
# 7         Health care             28
# 8         Industrials            109
# 9          Technology             38
# 10          Utilities             15

# %%
#Finding sectors with average founded year after 2000
rsql("SELECT Sector, AVG(Founded) as Avg_Founded_Year, COUNT(*) as Company_Count FROM company GROUP BY Sector HAVING AVG(Founded) > 2000")
# Out:
#                       Sector  Avg_Founded_Year  Company_Count
# 0                  Aerospace           2003.00              1
# 1         Alternative energy           2010.00              1
# 2  Consumer digital services           2005.12             25
# 3        Full line insurance           2009.00              2
# 4             Semiconductors           2005.00              1
# 5           Travel & tourism           2007.00              2

# %% [markdown]
# ## Using LIKE

# %%
#Searcing companies by name pattern using LIKE FUNCTION
rsql("SELECT Name, Industry, Headquarters FROM company WHERE Name LIKE '%Tech%'")
# Out:
#                                          Name            Industry Headquarters
# 0                       63 Moons Technologies          Technology       Mumbai
# 1                                      Aptech         Industrials       Mumbai
# 2                              Bharat Biotech         Health care    Hyderabad
# 3                          Dixon Technologies         Industrials        Noida
# 4                      Dynamatic Technologies         Industrials    Bengaluru
# 5                                     HCLTech         Industrials        Noida
# 6                          Intex Technologies      Consumer goods    New Delhi
# 7                           KPIT Technologies      Consumer goods         Pune
# 8                             Lanco Infratech        Conglomerate    New Delhi
# 9                   Protean eGov Technologies          Technology       Mumbai
# 10  Rail India Technical and Economic Service         Industrials     Gurugram
# 11                        Sasken Technologies         Industrials    Bengaluru
# 12                      Sterlite Technologies  Telecommunications         Pune
# 13                          Tata Technologies         Industrials         Pune
# 14                              Tech Mahindra         Industrials         Pune
# 15                           UltraTech Cement         Industrials       Mumbai
# 16                              Unitech Group         Real estate    New Delhi
# 17                              VA Tech Wabag           Utilities      Chennai
# 18                        Zensar Technologies          Technology         Pune

# %% [markdown]
# ## Using INSERT

# %%
#Inserting New Company into the data using INSERT FUNCTION
c.execute("""INSERT INTO company (Name, Industry, Sector, Headquarters, Founded, Notes, Ownership_Status, Present_Status) 
             VALUES ('New Tech Corp', 'Technology', 'Software', 'Bangalore', 2023, 'AI startup', 'P', 'A')""")
rsql("SELECT * from company WHERE Name = 'New Tech Corp'")
# Out:
#             Name    Industry    Sector Headquarters Founded       Notes  \
# 0  New Tech Corp  Technology  Software    Bangalore    2023  AI startup
# 1  New Tech Corp  Technology  Software    Bangalore    2023  AI startup
#
#   Ownership_Status Present_Status
# 0                P              A
# 1                P              A

# %% [markdown]
# ## Using UPDATE

# %%
# Updating company status
c.execute("""UPDATE company SET Headquarters = 'Bangalore' WHERE Name = '63 Moons Technologies'""")
rsql('SELECT * from company where "Industry" = "Technology" LIMIT 5')
# Out:
#                     Name    Industry                     Sector Headquarters  \
# 0  63 Moons Technologies  Technology                   Software    Bangalore
# 1               BluSmart  Technology  Consumer digital services     Gurugram
# 2        Cosmic Circuits  Technology             Semiconductors    Bengaluru
# 3                 Cyient  Technology     Software & IT services    Hyderabad
# 4               Flipkart  Technology  Consumer digital services    Bengaluru
#
#   Founded                                              Notes Ownership_Status  \
# 0    1988                               Financial technology                P
# 1    2019                        Taxi services, ride-sharing                P
# 2    2005           Acquired by Cadence Design Systems (USA)                P
# 3    1991  Engineering outsourcing services, software man...                P
# 4    2007                                         E-commerce                P
#
#   Present_Status
# 0              A
# 1              A
# 2              D
# 3              A
# 4              A

# %% [markdown]
# ## Using DISTINCT

# %%
#Finding the different headquarter cities
rsql(" SELECT DISTINCT(Headquarters) from company")
# Out:
#           Headquarters
# 0               Mumbai
# 1              Chennai
# 2            Ahmedabad
# 3              Kolkata
# 4            Faridabad
# 5            New Delhi
# 6               Kanpur
# 7           Vijayawada
# 8                Kochi
# 9             Gurugram
# 10               Anand
# 11               Delhi
# 12              Rajkot
# 13                Pune
# 14            Vadodara
# 15           Bengaluru
# 16           Hyderabad
# 17            Ludhiana
# 18            Palakkad
# 19          Kumbakonam
# 20            Thrissur
# 21           Ghaziabad
# 22              Panaji
# 23               Noida
# 24         Navi Mumbai
# 25              Nagpur
# 26                 Goa
# 27            Tinsukia
# 28             Bikaner
# 29       Visakhapatnam
# 30             Udaipur
# 31  Thiruvananthapuram
# 32         Tirunelveli
# 33            Dehradun
# 34             Jalgaon
# 35              Mysuru
# 36           Mangaluru
# 37               Karur
# 38          Coimbatore
# 39              Karnal
# 40           Sambalpur
# 41              Ranchi
# 42               Erode
# 43           Raebareli
# 44         Bhubaneswar
# 45              Jaipur
# 46             Neyveli
# 47            Duliajan
# 48            Haridwar
# 49          Chennai[7]
# 50              Rajula
# 51             Lucknow
# 52             Belgaum
# 53          Kothagudem
# 54         Thoothukudi
# 55  Mumbai and Kolkata
# 56              Mohali

# %%
#Finding the years with the most number of companies founded
rsql(""" SELECT Distinct(Founded) as Founding_Year, Count(Name) as Number_of_Companies_Founded 
from company GROUP BY Founded 
ORDER BY Count(Name)  DESC """)
# Out:
#     Founding_Year  Number_of_Companies_Founded
# 0            1986                           12
# 1            1995                           11
# 2            1983                            9
# 3            1981                            9
# 4            1979                            9
# ..            ...                          ...
# 126          1806                            1
# 127          1788                            1
# 128          1775                            1
# 129          1767                            1
# 130          1736                            1
#
# [131 rows x 2 columns]

# %%
#Given the nature of the dataset, we did not find any suitable use of the 'SUM' function
